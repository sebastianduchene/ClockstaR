# %%
library(ape)

# %%
gene_58Sa <- read.dna('~/Downloads/58Sa.fasta', 'fasta')
gene_cp <- read.dna('cp_resta.fasta', 'fasta')
gene_its <- read.dna('ITSa.fasta', 'fasta')
gene_trn <- read.dna('trnLa.fasta', 'fasta')

tree <- read.tree('BI_final_tree.tre')

# %%
plot(tree, show.tip.label = F)
# Out:
# plot without title

# %% [markdown]
# ### List of taxa in the tree, but not in 58Sa

# %%
print(tree$tip.label[!tree$tip.label %in% rownames(gene_58Sa)])
# Out:
#  [1] "S_ruprechtiana_Sax84"
#  [2] "'S_federici-augusti_subsp._grisebachii__Youguslavia_NEU_219945_JE199'"
#  [3] "'S.bulleyana__China_KUN_0262942_JE48'"
#  [4] "'S_prattii_var._obtusata__China_KUN_KUN0261026_1976_JE175'"
#  [5] "S_cortusifolia_Sax024"
#  [6] "Ribes_aureum"
#  [7] "Micranthes_punctata"
#  [8] "S_foliolosa"
#  [9] "Chrysosplenium_americanum__USA_M_AhleS_76381_1973_JE137"
# [10] "Bergenia_cordifolia_Guo0802"
# [11] "Mitella_doiana"
# [12] "Mitella_kiusiana"
# [13] "Mitella_pauciflora"
# [14] "Mitella_formosana"
# [15] "Mitella_integripetala"
# [16] "Heuchera_sanguinea__China_KUN_0255704_1975_JE147"
# [17] "Boykinia_richardsonii"
# [18] "Sullivantia_sullivantii"

# %% [markdown]
# ### List of taxa in the tree, but not in cp

# %%
print(tree$tip.label[!tree$tip.label %in% rownames(gene_cp)])
# Out:
#  [1] "S_pseudolaevis_Sax71"
#  [2] "'S_federici-augusti_subsp._grisebachii__Youguslavia_NEU_219945_JE199'"
#  [3] "S_cochlearis_Sax213"
#  [4] "S_portosanctana__AJ233883"
#  [5] "S_cossoniana"
#  [6] "S_intricata_Nat"
#  [7] "S_nevadensis__AF261185"
#  [8] "S_genesiana__KJ774142"
#  [9] "S_seguieri_Sax161"
# [10] "S_insolens__EU158841"
# [11] "S_xiaozhongdianensis__EU158835"
# [12] "S_hookeri__EU158840"
# [13] "S_pseudohirculus_Sax275"
# [14] "'S.bulleyana__China_KUN_0262942_JE48'"
# [15] "S_tatsienluensis__EU158845"
# [16] "'S_prattii_var._obtusata__China_KUN_KUN0261026_1976_JE175'"
# [17] "S_dingqingensis__EU158857"
# [18] "S_zhidoensis__EU158862"
# [19] "Lithophragma_glabrum"
# [20] "Lithophragma_bolanderi"
# [21] "Lithophragma_maximum_AF158941"
# [22] "Astilbe_platyphylla_SAPS_Ko"
# [23] "Boykinia_aconitifolia"
# [24] "Boykinia_lycoctonifolia"

# %% [markdown]
# ### List of taxa in the tree, but not in its

# %%
print(tree$tip.label[!tree$tip.label %in% rownames(gene_its)])
# Out:
#  [1] "S_ruprechtiana_Sax84"
#  [2] "'S_federici-augusti_subsp._grisebachii__Youguslavia_NEU_219945_JE199'"
#  [3] "'S.bulleyana__China_KUN_0262942_JE48'"
#  [4] "'S_prattii_var._obtusata__China_KUN_KUN0261026_1976_JE175'"
#  [5] "S_cortusifolia_Sax024"
#  [6] "Ribes_aureum"
#  [7] "Micranthes_punctata"
#  [8] "S_foliolosa"
#  [9] "Chrysosplenium_americanum__USA_M_AhleS_76381_1973_JE137"
# [10] "Bergenia_cordifolia_Guo0802"
# [11] "Mitella_doiana"
# [12] "Mitella_kiusiana"
# [13] "Mitella_pauciflora"
# [14] "Mitella_formosana"
# [15] "Mitella_integripetala"
# [16] "Heuchera_sanguinea__China_KUN_0255704_1975_JE147"
# [17] "Boykinia_richardsonii"
# [18] "Sullivantia_sullivantii"

# %% [markdown]
# ### List of taxa in the tree, but not in trn

# %%
print(tree$tip.label[!tree$tip.label %in% rownames(gene_trn)])
# Out:
#  [1] "S_pseudolaevis_Sax71"
#  [2] "'S_federici-augusti_subsp._grisebachii__Youguslavia_NEU_219945_JE199'"
#  [3] "S_cochlearis_Sax213"
#  [4] "S_portosanctana__AJ233883"
#  [5] "S_cossoniana"
#  [6] "S_intricata_Nat"
#  [7] "S_nevadensis__AF261185"
#  [8] "S_genesiana__KJ774142"
#  [9] "S_insolens__EU158841"
# [10] "S_xiaozhongdianensis__EU158835"
# [11] "S_hookeri__EU158840"
# [12] "'S.bulleyana__China_KUN_0262942_JE48'"
# [13] "S_tatsienluensis__EU158845"
# [14] "'S_prattii_var._obtusata__China_KUN_KUN0261026_1976_JE175'"
# [15] "S_dingqingensis__EU158857"
# [16] "S_zhidoensis__EU158862"
# [17] "S_strigosa"
# [18] "S_stelleriana"
# [19] "S_caulescens"
# [20] "S_nishidae"
# [21] "S_rebunshirensis"
# [22] "S_bronchialis_subsp_funstonii"
# [23] "S_vespertina"
# [24] "Ribes_alpestre"
# [25] "Ribes_oxyacanthoides"
# [26] "Ribes_nigrum"
# [27] "Ribes_aureum"
# [28] "Itea_chinensis"
# [29] "S_foliolosa"
# [30] "Chrysosplenium_ramosum"
# [31] "Tiarella_cordifolia"
# ...
